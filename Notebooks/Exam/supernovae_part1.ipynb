# %% [markdown]
# # Supernova distances and redshifts (Part 1)

# %% [markdown]
# # Examinable
# - First, explore fitting this data with the tecniques we have seen.
# - Start from linear regression and polynomial regression
# - For the case of polynomial regression, just fit many of them for now.
# - Let's bet based on intuition! Which fit is the best?
# - In what cases are you underfitting the data?
# - In what cases are you overfitting the data?
# - Now split the data into training and validation sets
# - Implement a cross-validation procedure
# - Pick the best!
# - Does it agree with our bets?

# %%
import numpy as np
from astroML.datasets import generate_mu_z
z_sample, mu_sample, dmu = generate_mu_z(100, random_state=1234)

# %%
import sys
sys.path.append(r"C:\Users\ricca\Documents\Unimib-Code\AstroStatistics\Notebooks")
from Utilities import plot_settings
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Data Exploration

# %%
plt.errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1,label='data')
plt.xlabel(r"$\mathcal{z}$")
plt.ylabel(r"$\mu$")
plt.legend(loc='lower right')
plt.title('Raw Data')
# Out:
# Text(0.5, 1.0, 'Raw Data')

# %%
data = pd.DataFrame(
    {'z' : z_sample,
     'mu' : mu_sample,
     'dmu' : dmu}
)

# %%
from scipy.stats import norm, kstest

# %%
sns.set_theme(style="whitegrid", context="talk")
dmu_fit = np.linspace(min(dmu), max(dmu), 100)
# Compute stats
mean = data['dmu'].mean()
std = data['dmu'].std()
n = norm(mean, std).pdf(dmu_fit)
# Plot
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
sns.histplot(data['dmu'], bins='scott', kde=True, color='skyblue', edgecolor='black')

# Add vertical lines for mean and ±1σ
plt.axvline(mean, color='red', linestyle='--', label=f'Mean = {mean:.2f}')
plt.axvline(mean + std, color='green', linestyle=':', label=f'+1σ = {mean + std:.2f}')
plt.axvline(mean - std, color='green', linestyle=':', label=f'-1σ = {mean - std:.2f}')
plt.plot(dmu_fit, n, color='orange', lw=2, label=f'G({mean:.2f}, {std:.2f})')

# Labels and title
plt.xlabel("Δμ", fontsize=14)
plt.ylabel("Counts", fontsize=14)
plt.title("Errors Distribution", fontsize=16)
plt.legend()

plt.subplot(1, 2, 2)
plt.scatter(dmu, z_sample, lw=2, color='red', marker='.')
plt.xlabel("z", fontsize=14)
plt.ylabel("Δμ", fontsize=14)
plt.tight_layout()

# %% [markdown]
# Is the error distribution gaussian? $\to$ Kolmogorov-Smirnoff test

# %%
mu, sigma = np.mean(dmu), np.std(dmu)
ks_stat, ks_p = kstest(dmu, 'norm', args=(mu, sigma))
print('Threshold : 5%')
print(f"Kolmogorov–Smirnov Test:\nStatistic = {ks_stat:.4f}, p-value = {ks_p*100:.4} %")
print(f'Gaussian distribution moments: mu = {mu:.2}, sigma = {sigma:.2}')
# Out:
# Threshold : 5%
# Kolmogorov–Smirnov Test:
# Statistic = 0.1088, p-value = 17.43 %
# Gaussian distribution moments: mu = 0.95, sigma = 0.032

# %% [markdown]
# So I have not strong enough evidence to reject the null hypothesis ('Errors distribution is normal'). I am facing a regression task were my sample exhibits homoscedastic Gaussian errors.

# %%
import random
random_seed = 54

np.random.seed(random_seed)
random.seed(random_seed)

# %%
def train_test_cv_split(x_data, train_pc=0.5, cv_pc=0.25, test_pc=0.25):
    """Shuffle and split data into train, CV, and test sets."""

    # Make sure the proportions sum to 1
    assert np.isclose(train_pc + cv_pc + test_pc, 1.0), "Proportions must sum to 1.0"

    n = len(x_data)
    indices = np.arange(n)
    np.random.shuffle(indices)

    # Compute split sizes
    n_train = int(train_pc * n)
    n_cv = int(cv_pc * n)

    # Slice indices
    train_idx = indices[:n_train]
    cv_idx = indices[n_train:n_train + n_cv]
    test_idx = indices[n_train + n_cv:]

    return x_data[train_idx], x_data[cv_idx], x_data[test_idx]

# %%
X = np.vstack([z_sample, mu_sample, dmu]).T

# %%
X_train, X_cv, X_test = train_test_cv_split(X, train_pc=0.5, cv_pc=0.4, test_pc=0.1)

# %%
plt.errorbar(X_train[:, 0], X_train[:, 1], yerr=X_train[:, 2], fmt='.k', ecolor='k', lw=1,label='train_data')
plt.errorbar(X_cv[:, 0], X_cv[:, 1], yerr=X_cv[:, 2], fmt='.k', ecolor='blue', lw=1,label='cv_data')
plt.errorbar(X_test[:, 0], X_test[:, 1], yerr=X_test[:, 2], fmt='.k', ecolor='red', lw=1,label='test_data')
plt.xlabel(r"$\mathcal{z}$")
plt.ylabel(r"$\mu$")
plt.legend(loc='lower right')
plt.title('Raw Data')
# Out:
# Text(0.5, 1.0, 'Raw Data')

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
z = X_train[:, 0]
mu = X_train[:, 1]
dmu = X_train[:, 2]

LR = LinearRegression()
LR.fit(z.reshape(-1, 1), mu)


def compute_ci(z, mu, y_pred):

    # Calculate confidence interval
    n = len(z)
    z_sorted = np.sort(z)
    X_design = np.vstack([np.ones(n), z]).T
    pred_var = np.sum((mu - y_pred)**2) / (n - 2)
    XTX_inv = np.linalg.inv(X_design.T @ X_design) #inverse of covariance matrix

    # Compute confidence bands
    ci = []
    for i in range(n):
        x0 = np.array([1, z[i]])
        se = np.sqrt(pred_var * x0 @ XTX_inv @ x0.T)
        ci.append(1.96 * se)
        
    ci = np.array(ci)
    sort_idx = np.argsort(z)
    z_sorted = z[sort_idx]
    y_pred_sorted = y_pred[sort_idx]
    ci_sorted = ci[sort_idx]
    return z_sorted, y_pred_sorted, ci_sorted

# %%
x_fit = np.linspace(z.min(), z.max(), 1000)
y_fit = LR.predict(x_fit.reshape(-1, 1))

plt.figure(figsize=(10,5))
plt.errorbar(z, mu, yerr=dmu, fmt='.', color='black', ecolor='black', lw=1, label='Train data')
plt.plot(X_test[:, 0], LR.predict(X_test[:, 0].reshape(-1,1)), color='blue', lw=2, label='Linear fit')
plt.errorbar(X_test[:, 0], X_test[:, 1], yerr=X_test[:, 2], fmt='.', color='k', ecolor='b', lw=1, label='Test data')

z_sorted, y_pred_sorted, ci_sorted = compute_ci(z, mu, LR.predict(z.reshape(-1, 1)))
plt.plot(z_sorted, y_pred_sorted, color='red', lw=2, label='Linear fit')
plt.fill_between(z_sorted, y_pred_sorted - ci_sorted, y_pred_sorted + ci_sorted, 
                 color='red', alpha=0.3, label='95% CI')

z_sorted, y_pred_sorted, ci_sorted = compute_ci(X_test[:, 0], X_test[:, 1], LR.predict(X_test[:, 0].reshape(-1, 1)))
plt.fill_between(z_sorted, y_pred_sorted - ci_sorted, y_pred_sorted + ci_sorted, 
                 color='b', alpha=0.3, label='95% CI')

plt.xlabel(r"$\mathcal{z}$", fontsize=14)
plt.ylabel(r"$\mu$", fontsize=14)
plt.title("Fit on training data", fontsize=15)
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# 1. Define polinomial degrees to fit the data with
# 2. Train models on training set and compute RMSE_train
# 3. Perform K-Fold Cross validation and compute RMSE_cv
# 4. Plot results
# 5. Plot errors vs degree

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.model_selection import learning_curve

# %%
degrees = [2, 4, 10]

x_fit = np.linspace(X_train[:, 0].min(), X_train[:, 0].max(), 1000).reshape(-1, 1)

fig, axes = plt.subplots(1, len(degrees), figsize=(6 * len(degrees), 5), sharey=True)

for i, deg in enumerate(degrees):
    ax = axes[i]

    model = Pipeline([
        ('poly', PolynomialFeatures(degree=deg)),
        ('linear', LinearRegression())
    ])
    model.fit(X_train[:, 0].reshape(-1, 1), mu)

    y_fit = model.predict(x_fit)
    y_test_pred = model.predict(X_test[:, 0].reshape(-1, 1))
    
    ax.errorbar(X_train[:, 0], X_train[:, 1], yerr=dmu, fmt='.', color='black', ecolor='black', lw=1, label='Train data')
    ax.plot(x_fit, y_fit, color='red', lw=2, label=f'Degree {deg} fit')    
    z_sorted, y_pred_sorted, ci_sorted = compute_ci(X_train[:, 0], X_train[:, 1], model.predict(X_train[:, 0].reshape(-1, 1)))
    ax.fill_between(z_sorted, y_pred_sorted - ci_sorted, y_pred_sorted + ci_sorted, 
                    color='red', alpha=0.3, label='Train 95% CI')

    ax.set_title(f"Degree {deg}")
    ax.set_xlabel(r"$\mathcal{z}$", fontsize=14)
    if i == 0:
        ax.set_ylabel(r"$\mu$", fontsize=14)
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=10)

plt.ylim(25,50)
plt.tight_layout()
plt.show()

# %% [markdown]
# As shown in the plot above, a $2^{th}$ degree polynomial is ok, a $4^{th}$ degree polynomial captures more of the data structure without being greatly influenced by the data variance, as the $10^{th}$ degree polynomial does. For a more quantitative analysis, I'll cross validate

# %%
pipe = Pipeline([
    ('poly', PolynomialFeatures()),
    ('linear', LinearRegression())
])

param_grid = {'poly__degree': list(np.linspace(1,10,10,dtype=int))}

custom_cv = KFold(n_splits=10, shuffle=True, random_state=42)

grid = GridSearchCV(pipe, param_grid, cv=custom_cv, scoring='neg_mean_squared_error', return_train_score=True, refit=True)
grid.fit(X_cv[:, 0].reshape(-1, 1), X_cv[:, 1])

best_degree = grid.best_params_['poly__degree']

# %%
degrees = grid.cv_results_['param_poly__degree'].data
train_rmse = np.sqrt(-grid.cv_results_['mean_train_score'])
val_rmse = np.sqrt(-grid.cv_results_['mean_test_score'])

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(degrees, train_rmse, 'o-', label='Training RMSE', color='blue')
plt.xlabel('Polynomial Degree')
plt.ylabel('RMSE')
plt.xticks(degrees)
plt.legend()
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(degrees, val_rmse, 'o-', label='Validation RMSE', color='orange')
plt.axhline(np.min(val_rmse), 0, 1, color='red', linestyle='--', label='min(CV error)')
plt.xlabel('Polynomial Degree')
plt.ylabel('RMSE')
plt.xticks(degrees)
plt.legend()
#plt.yscale('log')
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# As showed in the plots above, as the polynomial degree increases, the training MSE decreases since the number of parameters grows and thus it is easier for the model to best fit the data. At the same time CV MSE increases after $4^{th}$ degree. But how does the model perform with unseen data (namely test set)?

# %%
from sklearn.metrics import mean_squared_error


model = Pipeline([
    ('poly', PolynomialFeatures(degree=4)),
    ('linear', LinearRegression())
])
model.fit(X_train[:, 0].reshape(-1, 1), mu)

y_fit = model.predict(x_fit)
y_test_pred = model.predict(X_test[:, 0].reshape(-1, 1))

# Compute performance metrics
mse = mean_squared_error(X_test[:, 1], y_test_pred)

print(f"Final Test Set Evaluation:")
print(f"  Mean Squared Error (MSE): {mse:.4f}")

plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
#plt.errorbar(X_train[:, 0], X_train[:, 1], yerr=X_train[:, 2], fmt='.', color='black', ecolor='black', lw=1, label='Train data')
plt.plot(x_fit, y_fit, color='red', lw=2, label=f'Degree {4} fit')
plt.errorbar(X_test[:, 0], X_test[:, 1], yerr=X_test[:, 2], fmt='.', color='blue', ecolor='blue', lw=1, label='Test data')
plt.scatter(X_test[:, 0], y_test_pred, marker='.', color='red', label='Predicted data')
z_sorted, y_pred_sorted, ci_sorted = compute_ci(X_test[:, 0], X_test[:, 1], model.predict(X_test[:, 0].reshape(-1, 1)))
plt.fill_between(z_sorted, y_pred_sorted - ci_sorted, y_pred_sorted + ci_sorted, 
                color='red', alpha=0.3, label='Test 95% CI')
plt.legend()
plt.xlabel('z')
plt.ylabel(r'$\mu$')

plt.subplot(1, 2, 2)
plt.scatter(X_test[:, 0], abs(y_test_pred - X_test[:, 1]), marker='.', color='red', label='Predicted data')
plt.xlabel('z')
plt.ylabel('Residuals')
# Out:
# Final Test Set Evaluation:
#   Mean Squared Error (MSE): 0.7617
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# # Optional

# %% [markdown]
# ## Basis Function Regression (Gaussians)

# %%
z_train = X_train[:, 0]
z_test  = X_test[:, 0]
mu_train = X_train[:, 1]
mu_test = X_test[:, 1]
dmu_test = X_test[:, 2]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import learning_curve, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin

# Custom transformer: Gaussian basis functions
class GaussianBasis(BaseEstimator, TransformerMixin):
    def __init__(self, n_centers=10, sigma=1.0):
        self.n_centers = n_centers
        self.sigma = sigma

    def fit(self, X, y=None):
        X = X.reshape(-1, 1)
        self.centers_ = np.linspace(X.min(), X.max(), self.n_centers).reshape(-1, 1)
        return self

    def transform(self, X):
        X = X.reshape(-1, 1)
        return np.exp(-((X - self.centers_.T) ** 2) / (2 * self.sigma ** 2))

# Define pipeline
pipe = Pipeline([
    ('gauss', GaussianBasis()),  
    ('linreg', LinearRegression())
])

# Grid search parameters
param_grid = {
    'gauss__n_centers': list(np.linspace(1, 20, 20, dtype=int)),
    'gauss__sigma': list(np.power(10, np.linspace(-3, 3, 7)))
}

# Fit GridSearchCV
grid = GridSearchCV(pipe, param_grid, cv=custom_cv, scoring='neg_mean_squared_error', verbose=3)
grid.fit(z_train.reshape(-1, 1), mu_train)
# Out:
# Fitting 10 folds for each of 140 candidates, totalling 1400 fits
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-1.282 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-5.208 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-0.242 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-2.152 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-2.127 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-1.891 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-1.206 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-8.384 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-3.056 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-11.085 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-1.216 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-5.002 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-0.277 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.157 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.014 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.023 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-1.176 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-8.344 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.992 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-10.210 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.060 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-4.130 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-0.665 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.834 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.381 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.257 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.059 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-3.245 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-2.332 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-2.817 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-1.066 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.914 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.904 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.521 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-1.953 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.562 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-1.771 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-3.223 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.324 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-4.642 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.830 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-1.270 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.725 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.748 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-1.965 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.573 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-1.803 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-3.707 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.382 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-5.303 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.828 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-1.274 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.724 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.751 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-1.965 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.573 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-1.804 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-3.713 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.384 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-5.311 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-0.828 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-1.274 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-0.724 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-0.751 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-1.965 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-0.573 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-1.804 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-3.713 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-0.384 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-5.311 total time=   0.0s
# [CV 1/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-1.373 total time=   0.0s
# [CV 2/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-5.447 total time=   0.0s
# [CV 3/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-0.217 total time=   0.0s
# [CV 4/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-2.162 total time=   0.0s
# [CV 5/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-2.273 total time=   0.0s
# [CV 6/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-1.764 total time=   0.0s
# [CV 7/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-1.253 total time=   0.0s
# [CV 8/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-8.009 total time=   0.0s
# [CV 9/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-3.144 total time=   0.0s
# [CV 10/10] END gauss__n_centers=2, gauss__sigma=0.001;, score=-10.861 total time=   0.0s
# [CV 1/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-1.381 total time=   0.0s
# [CV 2/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-2.314 total time=   0.0s
# [CV 3/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-0.217 total time=   0.0s
# [CV 4/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-2.163 total time=   0.0s
# [CV 5/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-2.289 total time=   0.0s
# [CV 6/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-1.763 total time=   0.0s
# [CV 7/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-1.257 total time=   0.0s
# [CV 8/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-7.634 total time=   0.0s
# [CV 9/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-3.152 total time=   0.0s
# [CV 10/10] END gauss__n_centers=2, gauss__sigma=0.01;, score=-7.777 total time=   0.0s
# [CV 1/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-0.906 total time=   0.0s
# [CV 2/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-1.865 total time=   0.0s
# [CV 3/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-0.506 total time=   0.0s
# [CV 4/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-1.774 total time=   0.0s
# [CV 5/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-1.635 total time=   0.0s
# [CV 6/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-1.054 total time=   0.0s
# [CV 7/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-1.043 total time=   0.0s
# [CV 8/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-2.974 total time=   0.0s
# [CV 9/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-2.469 total time=   0.0s
# [CV 10/10] END gauss__n_centers=2, gauss__sigma=0.1;, score=-1.138 total time=   0.0s
# [CV 1/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-1.512 total time=   0.0s
# [CV 2/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-1.201 total time=   0.0s
# [CV 3/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-1.324 total time=   0.0s
# [CV 4/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-0.148 total time=   0.0s
# [CV 5/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-1.551 total time=   0.0s
# [CV 6/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-0.593 total time=   0.0s
# [CV 7/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-1.201 total time=   0.0s
# [CV 8/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-1.951 total time=   0.0s
# [CV 9/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-0.835 total time=   0.0s
# [CV 10/10] END gauss__n_centers=2, gauss__sigma=1.0;, score=-2.192 total time=   0.0s
# [CV 1/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-1.398 total time=   0.0s
# [CV 2/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-1.039 total time=   0.0s
# [CV 3/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-1.265 total time=   0.0s
# [CV 4/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-0.162 total time=   0.0s
# [CV 5/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-1.486 total time=   0.0s
# [CV 6/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-0.559 total time=   0.0s
# [CV 7/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-1.127 total time=   0.0s
# [CV 8/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-1.902 total time=   0.0s
# [CV 9/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-0.854 total time=   0.0s
# [CV 10/10] END gauss__n_centers=2, gauss__sigma=10.0;, score=-1.786 total time=   0.0s
# [CV 1/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-1.397 total time=   0.0s
# [CV 2/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-1.038 total time=   0.0s
# [CV 3/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-1.264 total time=   0.0s
# [CV 4/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-0.162 total time=   0.0s
# [CV 5/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-1.485 total time=   0.0s
# [CV 6/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-0.559 total time=   0.0s
# [CV 7/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-1.126 total time=   0.0s
# [CV 8/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-1.902 total time=   0.0s
# [CV 9/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-0.855 total time=   0.0s
# [CV 10/10] END gauss__n_centers=2, gauss__sigma=100.0;, score=-1.782 total time=   0.0s
# [CV 1/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-1.397 total time=   0.0s
# [CV 2/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-1.038 total time=   0.0s
# [CV 3/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-1.264 total time=   0.0s
# [CV 4/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-0.162 total time=   0.0s
# [CV 5/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-1.485 total time=   0.0s
# [CV 6/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-0.559 total time=   0.0s
# [CV 7/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-1.126 total time=   0.0s
# [CV 8/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-1.902 total time=   0.0s
# [CV 9/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-0.855 total time=   0.0s
# [CV 10/10] END gauss__n_centers=2, gauss__sigma=1000.0;, score=-1.782 total time=   0.0s
# [CV 1/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-1.361 total time=   0.0s
# [CV 2/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-5.421 total time=   0.0s
# [CV 3/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-0.220 total time=   0.0s
# [CV 4/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-2.160 total time=   0.0s
# [CV 5/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-2.256 total time=   0.0s
# [CV 6/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-1.784 total time=   0.0s
# [CV 7/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-1.246 total time=   0.0s
# [CV 8/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-8.090 total time=   0.0s
# [CV 9/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-3.144 total time=   0.0s
# [CV 10/10] END gauss__n_centers=3, gauss__sigma=0.001;, score=-10.861 total time=   0.0s
# [CV 1/10] END gauss__n_centers=3, gauss__sigma=0.01;, score=-1.369 total time=   0.0s
# [CV 2/10] END gauss__n_centers=3, gauss__sigma=0.01;, score=-2.300 total time=   0.0s
# [CV 3/10] END gauss__n_centers=3, gauss__sigma=0.01;, score=-0.220 total time=   0.0s
# [CV 4/10] END gauss__n_centers=3, gauss__sigma=0.01;, score=-2.161 total time=   0.0s
# [CV 5/10] END gauss__n_centers=3, gauss__sigma=0.01;, score=-2.271 total time=   0.0s
# [CV 6/10] END gauss__n_centers=3, gauss__sigma=0.01;, score=-1.784 total time=   0.0s
# [CV 7/10] END gauss__n_centers=3, gauss__sigma=0.01;, score=
total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-82.101 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-1.809 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-3763.524 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-15122.207 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-1.089 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-6.441 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-1377.302 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-8.022 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1739.699 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-93145.348 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.016 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.197 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-38.058 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-2.008 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-0.568 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-11.370 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-854.320 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-425515.068 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.440 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.038 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.933 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.784 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.238 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.510 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.895 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-2.922 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.022 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.549 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.847 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.959 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.888 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.497 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-1.280 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.515 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.890 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-2.185 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-1.402 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.993 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-4.854 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-5.931 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-8.249 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-5.259 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-7.287 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-13.213 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-10.771 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-6.650 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-24.578 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-3.394 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-0.924 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-9.410 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-4.525 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.743 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-6.133 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.217 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-3.315 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-6.286 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-8.691 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-23.542 total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('gauss', GaussianBasis()),
#                                        ('linreg', LinearRegression())]),
#              param_grid={'gauss__n_centers': [np.int64(1), np.int64(2),
#                                               np.int64(3), np.int64(4),
#                                               np.int64(5), np.int64(6),
#                                               np.int64(7), np.int64(8),
#                                               np.int64(9), np.int64(10),
#                                               np.int64(11), np.int64(12),
#                                               np.int64(13), np.int64(14),
#                                               np.int64(15), np.int64(16),
#                                               np.int64(17), np.int64(18),
#                                               np.int64(19), np.int64(20)],
#                          'gauss__sigma': [np.float64(0.001), np.float64(0.01),
#                                           np.float64(0.1), np.float64(1.0),
#                                           np.float64(10.0), np.float64(100.0),
#                                           np.float64(1000.0)]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
best_model = grid.best_estimator_
best_params = grid.best_params_
print(f"Best Gaussian basis parameters: {best_params}")
# Out:
# Best Gaussian basis parameters: {'gauss__n_centers': np.int64(5), 'gauss__sigma': np.float64(1.0)}

# %%
z_test = np.linspace(z_train.min(), z_train.max(), 500).reshape(-1, 1)
mu_pred = best_model.predict(z_test)

plt.plot(z_test, mu_pred, 'r', lw=2, label="Best model fit")
plt.errorbar(X_train[:, 0], X_train[:, 1], yerr=dmu, fmt='.', color='black', ecolor='black', lw=1, label='Train data')
plt.errorbar(X_cv[:, 0], X_cv[:, 1], yerr=X_cv[:, 2], fmt='.', color='black', ecolor='blue', lw=1, label='CV data')
plt.xlabel("z")
plt.ylabel("μ(z)")
plt.title("Gaussian Basis Regression")
plt.legend()
plt.tight_layout()

# %%
train_sizes, train_scores, val_scores = learning_curve(
    best_model, z_train.reshape(-1, 1), mu_train,
    cv=custom_cv,
    scoring='neg_mean_squared_error',
    train_sizes=np.linspace(0.1, 1.0, 10),
    verbose=1
)

train_scores_mean = -np.mean(train_scores, axis=1)
val_scores_mean = -np.mean(val_scores, axis=1)
# Out:
# [learning_curve] Training set sizes: [ 4  9 13 18 22 27 31 36 40 45]
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.4s finished

# %%
plt.figure(figsize=(8, 5))
plt.plot(train_sizes, train_scores_mean, 'o-', label="Training error")
plt.plot(train_sizes, val_scores_mean, 'o-', label="Validation error")
plt.xlabel("Training set size")
plt.ylabel("Mean Squared Error")
plt.title("Learning Curves")
plt.yscale('log')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at learning curves, I can see that the RMSE errors on training and validation converge, but the error value overall is still high! This means that increasing the training set dimension is not usefull....I'd need a more complex model

# %% [markdown]
# ## Kernel regression (Nadaraya-Watson)

# %%
from sklearn.base import RegressorMixin

# %%
class NadarayaWatson(BaseEstimator, RegressorMixin):
    def __init__(self, bandwidth=1.0):
        self.bandwidth = bandwidth

    def fit(self, X, y):
        self.X_train_ = X.reshape(-1, 1)
        self.y_train_ = y
        return self

    def predict(self, X):
        X = X.reshape(-1, 1)
        K = self._gaussian_kernel(X, self.X_train_)
        weights = K / K.sum(axis=1, keepdims=True)
        return weights.dot(self.y_train_)

    def _gaussian_kernel(self, X, X_train):
        # Pairwise squared Euclidean distances
        dists = (X - X_train.T)**2
        return np.exp(-dists / (2 * self.bandwidth ** 2))

# %%
# Define the bandwidth values to try
param_grid = {'bandwidth': list(np.power(10, np.linspace(-2,1,20)))}

# Perform 5-fold cross-validation
grid = GridSearchCV(NadarayaWatson(), param_grid, cv=custom_cv, scoring='neg_mean_squared_error')

# Fit on training data
grid.fit(z_train.reshape(-1, 1), mu_train)

# Best model and bandwidth
best_model = grid.best_estimator_
best_bandwidth = grid.best_params_['bandwidth']
print("Best bandwidth:", best_bandwidth)
# Out:
# Best bandwidth: 0.04281332398719394

# %%
# Predict on a smooth range for plotting
x_plot = np.linspace(z_train.min(), z_train.max(), 500).reshape(-1, 1)
y_plot = best_model.predict(x_plot)
y_pred = best_model.predict(X)
y_pred_test = best_model.predict(z_test.reshape(-1,1))

# Plot
plt.plot(z_test, mu_pred, 'r', lw=2, label="Best model fit")
plt.errorbar(X_train[:, 0], X_train[:, 1], yerr=dmu, fmt='.', color='black', ecolor='black', lw=1, label='Train data')
plt.errorbar(X_cv[:, 0], X_cv[:, 1], yerr=X_cv[:, 2], fmt='.', color='black', ecolor='blue', lw=1, label='CV data')
plt.xlabel("z")
plt.ylabel("μ(z)")
plt.title("Gaussian Basis Regression")
plt.legend()
plt.tight_layout()
# Out:
# C:\Users\ricca\AppData\Local\Temp\ipykernel_848\1676803456.py:13: RuntimeWarning: invalid value encountered in divide
#   weights = K / K.sum(axis=1, keepdims=True)

# %%
train_sizes, train_scores, val_scores = learning_curve(
    best_model, z_train.reshape(-1, 1), mu_train,
    cv=custom_cv,
    scoring='neg_mean_squared_error',
    train_sizes=np.linspace(0.1, 1.0, 10),
    verbose=1
)

train_scores_mean = -np.mean(train_scores, axis=1)
val_scores_mean = -np.mean(val_scores, axis=1)
# Out:
# [learning_curve] Training set sizes: [ 4  9 13 18 22 27 31 36 40 45]
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.2s finished

# %%
plt.figure(figsize=(8, 5))
plt.plot(train_sizes, train_scores_mean, 'o-', label="Training error")
plt.plot(train_sizes, val_scores_mean, 'o-', label="Validation error")
plt.xlabel("Training set size")
plt.ylabel("Mean Squared Error")
plt.title("Learning Curves")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
