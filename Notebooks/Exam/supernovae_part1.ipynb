# %% [markdown]
# # Supernova distances and redshifts (Part 1)

# %% [markdown]
# - First, explore fitting this data with the tecniques we have seen.
# - Start from linear regression and polynomial regression
# - For the case of polynomial regression, just fit many of them for now.
# - Let's bet based on intuition! Which fit is the best?
# - In what cases are you underfitting the data?
# - In what cases are you overfitting the data?
# - Now split the data into training and validation sets
# - Implement a cross-validation procedure
# - Pick the best!
# - Does it agree with our bets?

# %%
import numpy as np
from astroML.datasets import generate_mu_z
z_sample, mu_sample, dmu = generate_mu_z(100, random_state=1234)

# %%
import sys
sys.path.append(r"C:\Users\ricca\Documents\Unimib-Code\AstroStatistics\Notebooks")
from Utilities import plot_settings
import matplotlib.pyplot as plt

# %%
plt.errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1,label='data')
plt.xlabel(r"$\mathcal{z}$")
plt.ylabel(r"$\mu$")
plt.legend(loc='lower right')
plt.title('Raw Data')
# Out:
# Text(0.5, 1.0, 'Raw Data')

# %%
import random
random_seed = 54

np.random.seed(random_seed)
random.seed(random_seed)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
z_train, z_test, mu_train, mu_test, dmu_train, dmu_test = train_test_split(z_sample, mu_sample, dmu, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import chi2

# %%
lin_reg = LinearRegression()

# %%
from scipy.stats import t

# Training data
X = z_train.reshape(-1, 1)
y = mu_train.reshape(-1, 1)
n = len(X)

# Fit model
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Predictions on training data
y_pred = lin_reg.predict(X)

# Residuals and residual variance
residuals = y - y_pred
s_err = np.sqrt(np.sum(residuals**2) / (n - 2))
s2 = np.sum(residuals**2) / (len(y) - 2)

# Compute chi-squared
chi2 = np.sum((y - y_pred)**2 / s2)

# Points to predict and plot confidence bands
x_fit = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
y_fit = lin_reg.predict(x_fit)

# Mean of X
x_mean = np.mean(X)

# Calculate standard error of the predictions
se_fit = s_err * np.sqrt(
    1/n + (x_fit - x_mean)**2 / np.sum((X - x_mean)**2)
)

# t-statistic for 95% confidence interval
t_val = t.ppf(0.975, df=n-2)  # two-sided 95%

# Upper and lower confidence bands
upper = y_fit.flatten() + t_val * se_fit.flatten()
lower = y_fit.flatten() - t_val * se_fit.flatten()

# Plot

fig, axs = plt.subplots(2,1, sharex=True, figsize=(12,8))
axs[0].errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1,label='data')
axs[0].errorbar(z_test, mu_test, dmu_test, fmt='.r', ecolor='gray', lw=1,label='test data')
axs[0].errorbar(z_train, mu_train, dmu_train, fmt='.b', ecolor='gray', lw=1,label='train data')
axs[0].plot(x_fit, y_fit, 'k-', label='Fit')
axs[0].fill_between(x_fit.flatten(), lower, upper, color='gray', alpha=0.5, label='95% Confidence band')
axs[0].text(
    1.5, 40, s=r"$\chi^{2}_{0, \text{train}}=$"+f"{chi2/(len(z_train - 2)):.2}",
    fontsize=16
)
axs[0].legend()

axs[1].set_xlabel(r"$\mathcal{z}$")
axs[1].scatter(z_train, residuals, marker='.', color='b')
axs[1].set_title('Residuals')
# Out:
# Text(0.5, 1.0, 'Residuals')

# %% [markdown]
# This fit shows high residuals in all the measured redshift spectrum.
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import root_mean_squared_error

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

degrees = [2, 4, 10, 20]
colors = ['red', 'blue', 'green', 'gray']

kf = KFold(n_splits=10, shuffle=True, random_state=42)

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred)**2))

for deg, color in zip(degrees, colors):
    poly = PolynomialFeatures(degree=deg, include_bias=False)
    
    # Transform full training data once (for final fit)
    X_train_poly = poly.fit_transform(z_train.reshape(-1, 1))

    # --- KFold Cross-validation on training set ---
    cv_mses = []
    for train_idx, val_idx in kf.split(z_train):
        X_tr, X_val = z_train[train_idx], z_train[val_idx]
        y_tr, y_val = mu_train[train_idx], mu_train[val_idx]

        X_tr_poly = poly.fit_transform(X_tr.reshape(-1, 1))
        X_val_poly = poly.transform(X_val.reshape(-1, 1))

        model_cv = LinearRegression()
        model_cv.fit(X_tr_poly, y_tr)

        y_val_pred = model_cv.predict(X_val_poly)
        cv_mses.append(root_mean_squared_error(y_val, y_val_pred))
    cv_mse_mean = np.mean(cv_mses)
    print(f"Degree {deg} → CV RMSE: {cv_mse_mean:.3f}")

    # --- Fit on full training set ---
    model = LinearRegression()
    model.fit(X_train_poly, mu_train)

    X_test_poly = poly.transform(z_test.reshape(-1, 1))
    y_test_pred = model.predict(X_test_poly)

    test_mse = root_mean_squared_error(mu_test, y_test_pred)
    print(f"Degree {deg} → Test RMSE: {test_mse:.3f}")

    # --- Prepare smooth curve ---
    z_plot = np.linspace(min(z_sample), max(z_sample), 500).reshape(-1, 1)
    z_plot_poly = poly.transform(z_plot)
    mu_fit = model.predict(z_plot_poly)

    # --- Calculate residual variance ---
    y_train_pred = model.predict(X_train_poly)
    residuals = mu_train - y_train_pred
    n = len(mu_train)
    p = X_train_poly.shape[1]
    s_err = np.sqrt(np.sum(residuals**2) / (n - p - 1))  # degrees of freedom correction

    # --- Compute standard errors for confidence bands ---
    X_design = np.hstack([np.ones((n,1)), X_train_poly])  # add intercept
    X_plot_design = np.hstack([np.ones((z_plot_poly.shape[0],1)), z_plot_poly])
    cov_matrix = np.linalg.inv(X_design.T @ X_design)

    se_fit = np.array([
        np.sqrt(np.dot(x_row.T, np.dot(cov_matrix, x_row))) for x_row in X_plot_design
    ]) * s_err

    t_val = t.ppf(0.975, df=n - p - 1)

    upper = mu_fit.flatten() + t_val * se_fit
    lower = mu_fit.flatten() - t_val * se_fit

    # --- Plot ---
    plt.figure(figsize=(8, 6))
    plt.errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1, label='Data')
    plt.plot(z_plot, mu_fit, color=color, lw=2, label='Model fit')
    plt.fill_between(z_plot.flatten(), lower, upper, color=color, alpha=0.3, label='95% Confidence band')
    plt.errorbar(z_test, mu_test, dmu_test, fmt='.r', ecolor='gray', lw=1,label='test data')
    plt.xlabel(r"$z$")
    plt.ylabel(r"$\mu$")
    plt.title(f'Polynomial Regression (degree = {deg})')
    plt.legend(loc='lower right')
    plt.xlim(0, 2)
    plt.ylim(35, 50)
    plt.show()
# Out:
# Degree 2 → CV RMSE: 0.935
# Degree 2 → Test RMSE: 0.954
# Degree 4 → CV RMSE: 0.951
# Degree 4 → Test RMSE: 0.911
# Degree 10 → CV RMSE: 20.137
# Degree 10 → Test RMSE: 0.969
# Degree 20 → CV RMSE: 52591.499
# Degree 20 → Test RMSE: 0.990

# %% [markdown]
# Based on the four degrees I picked, the best fit is the $4^{th}$ degree polynomial; it is a good compromise between model complexity, degrees of freedom and how much the fit line intercepts data points.\
# Using low degrees polynomials determines underfitting, meaing less of the data structure is grabbed from the fit line. On the other hand using too high degree polynomials determines overfitting, i.e. the model gets extremely good at training but its predictive power decreases.\
# I can do better, cross validate on the number of degrees!

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV, KFold

pipe = Pipeline([
    ('poly', PolynomialFeatures()),
    ('linear', LinearRegression())
])

param_grid = {'poly__degree': list(np.linspace(1,20,20,dtype=int))}

custom_cv = KFold(n_splits=10, shuffle=True, random_state=42)

# Fit grid search on TRAIN data, NOT test data
grid = GridSearchCV(pipe, param_grid, cv=custom_cv, scoring='neg_mean_squared_error', return_train_score=True, refit=True)
grid.fit(z_train.reshape(-1, 1), mu_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('poly', PolynomialFeatures()),
#                                        ('linear', LinearRegression())]),
#              param_grid={'poly__degree': [np.int64(1), np.int64(2), np.int64(3),
#                                           np.int64(4), np.int64(5), np.int64(6),
#                                           np.int64(7), np.int64(8), np.int64(9),
#                                           np.int64(10), np.int64(11),
#                                           np.int64(12), np.int64(13),
#                                           np.int64(14), np.int64(15),
#                                           np.int64(16), np.int64(17),
#                                           np.int64(18), np.int64(19),
#                                           np.int64(20)]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
from sklearn.metrics import silhouette_score

# %%
best_model = grid.best_estimator_
best_degree = grid.best_params_['poly__degree']

print(f"Best polynomial degree: {best_degree}")

# Evaluate on test set once after model selection
from sklearn.metrics import mean_squared_error
y_test_pred = best_model.predict(z_test.reshape(-1, 1))
test_mse = mean_squared_error(mu_test, y_test_pred)
print(f"Test MSE with best model (degree {best_degree}): {test_mse:.3f}")
# Out:
# Best polynomial degree: 2
# Test MSE with best model (degree 2): 0.909

# %%
# Extract degrees, train and test scores
degrees = grid.cv_results_['param_poly__degree'].data.astype(int)
mean_train_scores = -grid.cv_results_['mean_train_score']  # Convert from negative MSE
mean_test_scores = -grid.cv_results_['mean_test_score']

# Plotting

fig, axs = plt.subplots(1,2)

axs[0].plot(degrees, mean_train_scores, label='Train Error', marker='o')
#plt.plot(degrees, mean_test_scores, label='CV Error', marker='s')
axs[0].set_xlabel('Polynomial Degree')
axs[0].set_ylabel('Mean Squared Error')
axs[0].set_title('Training Error')
axs[0].legend()

axs[1].plot(degrees, mean_test_scores, label='CV Error', marker='s')
axs[1].set_xlabel('Polynomial Degree')
axs[1].set_ylabel('Mean Squared Error')
axs[1].set_title('CV Error')
axs[1].legend()
axs[1].set_yscale('log')

# %% [markdown]
# As showed in the plots above, as the polynomial degree increases, the training MSE decreases since the number of parameters grows and thus it is easier for the model to best fit the data. At the same time CV MSE increases very rapidely! With a polynomial degree as low as 6 the model is greatly overfitting the data!

# %%
# Predictions on training data

lin_reg = grid.best_estimator_
y_pred = lin_reg.predict(X)

# Residuals and residual variance
residuals = y.ravel() - y_pred.ravel()
s_err = np.sqrt(np.sum(residuals**2) / (n - 2))
s2 = np.sum(residuals**2) / (len(y) - 2)

# Compute chi-squared
chi2 = np.sum((y - y_pred)**2 / s2)

# Points to predict and plot confidence bands
x_fit = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
y_fit = lin_reg.predict(x_fit)

# Mean of X
x_mean = np.mean(X)

# Calculate standard error of the predictions
se_fit = s_err * np.sqrt(
    1/n + (x_fit - x_mean)**2 / np.sum((X - x_mean)**2)
)

# t-statistic for 95% confidence interval
t_val = t.ppf(0.975, df=n-2)  # two-sided 95%

# Upper and lower confidence bands
upper = y_fit.flatten() + t_val * se_fit.flatten()
lower = y_fit.flatten() - t_val * se_fit.flatten()

# Plot

fig, axs = plt.subplots(2,1, sharex=True, figsize=(12,8))
axs[0].errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1,label='data')
axs[0].errorbar(z_test, mu_test, dmu_test, fmt='.r', ecolor='gray', lw=1,label='test data')
axs[0].errorbar(z_train, mu_train, dmu_train, fmt='.b', ecolor='gray', lw=1,label='train data')
axs[0].plot(x_fit, y_fit, 'k-', label='Fit')
axs[0].fill_between(x_fit.flatten(), lower, upper, color='gray', alpha=0.5, label='95% Confidence band')
axs[0].text(
    1.5, 40, s=r"$\chi^{2}_{0, \text{train}}=$"+f"{chi2/(len(z_train - 2)):.2}",
    fontsize=16
)
axs[0].legend()
axs[1].set_xlabel(r"$\mathcal{z}$")
axs[1].scatter(z_train, residuals, marker='.', color='b')
axs[1].set_title('Residuals')
# Out:
# Text(0.5, 1.0, 'Residuals')

# %% [markdown]
# ## Basis Function Regression (Gaussians)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class GaussianBasis(BaseEstimator, TransformerMixin):
    def __init__(self, n_centers=10, sigma=1.0):
        self.n_centers = n_centers
        self.sigma = sigma

    def fit(self, X, y=None):
        X = X.reshape(-1, 1)
        self.centers_ = np.linspace(X.min(), X.max(), self.n_centers).reshape(-1, 1)
        return self

    def transform(self, X):
        X = X.reshape(-1, 1)
        return np.exp(-((X - self.centers_.T) ** 2) / (2 * self.sigma ** 2))

# Create pipeline
pipe = Pipeline([
    ('gauss', GaussianBasis()),  # Your custom Gaussian transformer
    ('linreg', LinearRegression())
])

# Define parameter grid
param_grid = {
    'gauss__n_centers': list(np.linspace(1,20,20, dtype=int)),
    'gauss__sigma': list(np.power(10,np.linspace(-3,3,7)))
}

# Grid search with CV
grid = GridSearchCV(pipe, param_grid, cv=custom_cv, scoring='neg_mean_squared_error', verbose=3)
grid.fit(z_train.reshape(-1, 1), mu_train)

# Best model and parameters
best_model = grid.best_estimator_
best_params = grid.best_params_
print(f"Best Gaussian basis parameters: {best_params} | Best score")
# Out:
# Fitting 10 folds for each of 140 candidates, totalling 1400 fits
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-2.447 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-8.081 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-2.868 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-3.551 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-3.501 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-4.936 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-2.406 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-3.623 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-1.802 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=0.001;, score=-2.986 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.432 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-7.792 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.854 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-3.538 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-3.505 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-4.959 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.422 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-3.358 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-1.792 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=0.01;, score=-2.992 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.724 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-3.328 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-2.053 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-2.646 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-2.452 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-2.158 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-2.452 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.231 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-1.346 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=0.1;, score=-3.189 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.752 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-3.555 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-2.350 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-1.183 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-1.503 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-1.110 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.864 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-2.441 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.345 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=1.0;, score=-0.689 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.975 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-4.389 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-4.823 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-1.260 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-1.865 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-1.719 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.981 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-2.895 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.356 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=10.0;, score=-0.715 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.978 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-4.397 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-4.859 total time=   0.0s
# [CV 4/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-1.262 total time=   0.0s
# [CV 5/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-1.869 total time=   0.0s
# [CV 6/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-1.726 total time=   0.0s
# [CV 7/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.983 total time=   0.0s
# [CV 8/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-2.900 total time=   0.0s
# [CV 9/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.357 total time=   0.0s
# [CV 10/10] END gauss__n_centers=1, gauss__sigma=100.0;, score=-0.717 total time=   0.0s
# [CV 1/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-0.978 total time=   0.0s
# [CV 2/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=-4.397 total time=   0.0s
# [CV 3/10] END gauss__n_centers=1, gauss__sigma=1000.0;, score=
total time=   0.0s
# [CV 10/10] END gauss__n_centers=19, gauss__sigma=1.0;, score=-1.298 total time=   0.0s
# [CV 1/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-0.502 total time=   0.0s
# [CV 2/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-1.837 total time=   0.0s
# [CV 3/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-44.178 total time=   0.0s
# [CV 4/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-1.116 total time=   0.0s
# [CV 5/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-0.906 total time=   0.0s
# [CV 6/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-0.615 total time=   0.0s
# [CV 7/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-1.497 total time=   0.0s
# [CV 8/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-1.114 total time=   0.0s
# [CV 9/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-0.530 total time=   0.0s
# [CV 10/10] END gauss__n_centers=19, gauss__sigma=10.0;, score=-1.061 total time=   0.0s
# [CV 1/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-1.443 total time=   0.0s
# [CV 2/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-8.889 total time=   0.0s
# [CV 3/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-5.395 total time=   0.0s
# [CV 4/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-1.598 total time=   0.0s
# [CV 5/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-2.133 total time=   0.0s
# [CV 6/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-0.944 total time=   0.0s
# [CV 7/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-4.262 total time=   0.0s
# [CV 8/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-7.002 total time=   0.0s
# [CV 9/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-1.270 total time=   0.0s
# [CV 10/10] END gauss__n_centers=19, gauss__sigma=100.0;, score=-2.095 total time=   0.0s
# [CV 1/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-2.395 total time=   0.0s
# [CV 2/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-4.054 total time=   0.0s
# [CV 3/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-2.405 total time=   0.0s
# [CV 4/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-2.647 total time=   0.0s
# [CV 5/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-6.439 total time=   0.0s
# [CV 6/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-4.089 total time=   0.0s
# [CV 7/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-2.199 total time=   0.0s
# [CV 8/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-2.626 total time=   0.0s
# [CV 9/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-2.101 total time=   0.0s
# [CV 10/10] END gauss__n_centers=19, gauss__sigma=1000.0;, score=-6.236 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-2.537 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-7.910 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-94.580 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-3.574 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-3.476 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-1771497855950632878342144.000 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-38080937769965405077504.000 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-4.486 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-1.902 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=0.001;, score=-3.383 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-29968536.913 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-54.797 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-2.840 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-1.843 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-2.008 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-2.470 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-4638.894 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-3.552 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-639.841 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=0.01;, score=-6.340 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-0.901 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-55991145.010 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-187.635 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-74.867 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.236 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.407 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.621 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.444 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.061 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=0.1;, score=-1.271 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.518 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-9.152 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-21941.999 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.947 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.359 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.556 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.671 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.071 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-0.441 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=1.0;, score=-1.298 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.494 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-1.688 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-55.666 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-1.157 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.904 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.614 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-1.494 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-1.133 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-0.542 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=10.0;, score=-1.054 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-1.846 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-9.205 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-2.582 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-2.235 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-1.081 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-2.172 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-1.937 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-2.135 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-0.752 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=100.0;, score=-3.345 total time=   0.0s
# [CV 1/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.983 total time=   0.0s
# [CV 2/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-8.905 total time=   0.0s
# [CV 3/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-4.250 total time=   0.0s
# [CV 4/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-4.326 total time=   0.0s
# [CV 5/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.990 total time=   0.0s
# [CV 6/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.289 total time=   0.0s
# [CV 7/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.719 total time=   0.0s
# [CV 8/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-1.113 total time=   0.0s
# [CV 9/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.089 total time=   0.0s
# [CV 10/10] END gauss__n_centers=20, gauss__sigma=1000.0;, score=-2.913 total time=   0.0s
# Best Gaussian basis parameters: {'gauss__n_centers': np.int64(2), 'gauss__sigma': np.float64(10.0)} | Best score

# %%
# Predict on a smooth range for plotting
x_plot = np.linspace(z_train.min(), z_train.max(), 500).reshape(-1, 1)
y_plot = best_model.predict(x_plot)
y_pred = best_model.predict(X)
y_pred_test = best_model.predict(z_test.reshape(-1,1))

plt.errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1, label='Training data')
plt.errorbar(z_test, mu_test, dmu_test, fmt='.k', ecolor='red', lw=1, label='Test data')
plt.plot(x_plot, y_plot, color='blue', label='Gaussian basis fit')
mse = root_mean_squared_error(mu_test, y_pred_test)
plt.text(
    1.5, 41,s=f'RMSE(test) = {mse:.2}', fontsize=14
)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gaussian Basis Function Regression Fit')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Kernel regression (Nadaraya-Watson)

# %%
from sklearn.base import RegressorMixin

# %%
class NadarayaWatson(BaseEstimator, RegressorMixin):
    def __init__(self, bandwidth=1.0):
        self.bandwidth = bandwidth

    def fit(self, X, y):
        self.X_train_ = X.reshape(-1, 1)
        self.y_train_ = y
        return self

    def predict(self, X):
        X = X.reshape(-1, 1)
        K = self._gaussian_kernel(X, self.X_train_)
        weights = K / K.sum(axis=1, keepdims=True)
        return weights.dot(self.y_train_)

    def _gaussian_kernel(self, X, X_train):
        # Pairwise squared Euclidean distances
        dists = (X - X_train.T)**2
        return np.exp(-dists / (2 * self.bandwidth ** 2))

# %%
# Define the bandwidth values to try
param_grid = {'bandwidth': list(np.power(10, np.linspace(-2,1,20)))}

# Perform 5-fold cross-validation
grid = GridSearchCV(NadarayaWatson(), param_grid, cv=custom_cv, scoring='neg_mean_squared_error')

# Fit on training data
grid.fit(z_train.reshape(-1, 1), mu_train)

# Best model and bandwidth
best_model = grid.best_estimator_
best_bandwidth = grid.best_params_['bandwidth']
print("Best bandwidth:", best_bandwidth)
# Out:
# Best bandwidth: 0.04281332398719394

# %%
# Predict on a smooth range for plotting
x_plot = np.linspace(z_train.min(), z_train.max(), 500).reshape(-1, 1)
y_plot = best_model.predict(x_plot)
y_pred = best_model.predict(X)
y_pred_test = best_model.predict(z_test.reshape(-1,1))

# Plot
plt.errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1, label='Training data')
plt.plot(x_plot, y_plot, color='blue', label='Gaussian basis fit')
plt.errorbar(z_test, mu_test, dmu_test, fmt='.k', ecolor='red', lw=1, label='Test data')
mse = root_mean_squared_error(mu_test, y_pred_test)
plt.text(
    1.5, 41,s=f'RMSE(test) = {mse:.2}', fontsize=14
)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Nadaraya-Watson Fit')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Part 2

# %% [markdown]
# - The key ingredient in getting a good GPR fit is the choice of the kernel and its parameters.
# - Radial-basis function kernel (aka squared-exponential kernel) is a standard choice in the GPR world.
# - But check out what's available in the kernels submodule of sklearn.gaussian_process
# - Plot the expectation value of the fit as well as the resulting 1-$\sigma$ and 2-$\sigma$ contours.
# - Interpret the results.

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, Matern, RationalQuadratic
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

# %%
Kernels = []

# %%
def do_GPR_reg(kern, scaler, X_scaled, plot_scaled=False, plot_scaled_back=False):
    GPR = GaussianProcessRegressor(kernel=kern, n_restarts_optimizer=10)
    GPR.fit(X_scaled.T[0].reshape(-1,1), X_scaled.T[1].reshape(-1,1))
    
    if plot_scaled:
        # Predict on a smooth range for plotting
        x_plot = np.linspace(X_scaled.T[0].min(), X_scaled.T[0].max(), 500)
        y_plot, std = GPR.predict(x_plot.reshape(-1, 1), return_std=True)
        
        plt.scatter(X_scaled.T[0], X_scaled.T[1], marker='.', color='gray',label='Training data')
        plt.plot(x_plot, y_plot, color='blue', label='GPR fit')
        plt.fill_between(x_plot, y_plot-std, y_plot+std, color='blue', alpha=0.5, label=r'$1-\sigma$')
        plt.fill_between(x_plot, y_plot-2*std, y_plot+2*std, color='blue', alpha=0.2, label=r'$2-\sigma$')
        plt.xlabel(r'Scaled $z$')
        plt.ylabel(r'Scaled $\mu$')
        plt.title('Gaussian Process Regression (Scaled data))')
        plt.legend()
        plt.show()
        
    if plot_scaled_back:
        # Generate x values for plotting
        x_plot = np.linspace(X_scaled.T[0].min(), X_scaled.T[0].max(), 500).reshape(-1, 1)

        # Predict mean and std from GPR
        y_pred_scaled, y_std_scaled = GPR.predict(x_plot, return_std=True)

        # Stack mean prediction to shape (500, 2) for inverse transform
        temp_mean = np.hstack([x_plot, y_pred_scaled.reshape(-1, 1)])
        Y_pred = scaler.inverse_transform(temp_mean)

        # Create upper and lower bounds for inverse transform (mean ± std)
        temp_upper = np.hstack([x_plot, (y_pred_scaled + y_std_scaled).reshape(-1, 1)])
        temp_lower = np.hstack([x_plot, (y_pred_scaled - y_std_scaled).reshape(-1, 1)])

        temp_upper_2s = np.hstack([x_plot, (y_pred_scaled + 2*y_std_scaled).reshape(-1, 1)])
        temp_lower_2s = np.hstack([x_plot, (y_pred_scaled - 2*y_std_scaled).reshape(-1, 1)])

        Y_upper = scaler.inverse_transform(temp_upper)
        Y_lower = scaler.inverse_transform(temp_lower)

        Y_upper_2s = scaler.inverse_transform(temp_upper_2s)
        Y_lower_2s = scaler.inverse_transform(temp_lower_2s)

        # Extract the values
        z_scaled_back_fit = Y_pred.T[0]
        mu_scaled_back_fit = Y_pred.T[1]


        # Also get the training data back to original scale
        Y = scaler.inverse_transform(np.vstack([X_scaled.T[0], X_scaled.T[1]]).T)


        # Plot everything
        plt.errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1, label='Training data')
        plt.plot(z_scaled_back_fit, mu_scaled_back_fit, color='blue', label='GPR fit')
        plt.fill_between(z_scaled_back_fit, Y_lower.T[1], Y_upper.T[1], color='blue', alpha=0.5, label=r"$1-\sigma$")
        plt.fill_between(z_scaled_back_fit, Y_lower_2s.T[1], Y_upper_2s.T[1], color='blue', alpha=0.2, label=r"$2-\sigma$")
        plt.xlabel(r'$z$')
        plt.ylabel(r'$\mu$')
        plt.title('GPR fit - '+str(kern))
        plt.legend()
        plt.grid(True)
        plt.show()

def select_best_kernel(X, y, kernels, custom_cross_validator, scoring='neg_mean_squared_error', n_restarts_optimizer=10):
    """
    Cross-validate multiple kernels with hyperparameter optimization in each fold.

    Parameters:
    -----------
    X : array-like, shape (n_samples,)
        Input features (1D).
    y : array-like, shape (n_samples,)
        Target values.
    kernels : list of sklearn.gaussian_process.kernels.Kernel
        List of kernel objects to evaluate.
    cv : int, default=5
        Number of cross-validation folds.
    scoring : str, default='neg_mean_squared_error'
        Scoring metric used by cross_val_score.
    n_restarts_optimizer : int, default=10
        Number of restarts for kernel hyperparameter optimizer during fitting.

    Returns:
    --------
    best_kernel : sklearn.gaussian_process.kernels.Kernel
        The kernel with the best average CV score.
    scores_dict : dict
        Dictionary mapping kernel string repr to average CV score.
    """

    best_kernel = None
    best_score = -np.inf
    scores_dict = {}

    for kern in kernels:
        gpr = GaussianProcessRegressor(kernel=kern, n_restarts_optimizer=n_restarts_optimizer)
        
        scores = cross_val_score(
            gpr,
            X.reshape(-1, 1),
            y,
            cv=custom_cross_validator,
            scoring=scoring,
            n_jobs=-1
        )
        mean_score = np.mean(scores)
        scores_dict[str(kern)] = mean_score
        print(f"Kernel: {kern}\n Mean CV Score: {mean_score:.5f}\n")

        if mean_score > best_score:
            best_score = mean_score
            best_kernel = kern

    print(f"Best kernel selected: {best_kernel}\nwith CV score: {best_score:.5f}")
    return best_kernel, scores_dict

# %%
Base_Kernels = [
    RBF(length_scale=0.001, length_scale_bounds=(1e-8, 1e8)) + WhiteKernel(noise_level=1.0, noise_level_bounds=(1e-10, 1e+1)),
    Matern(length_scale=0.001, length_scale_bounds=(1e-8, 1e8)) + WhiteKernel(noise_level=1.0, noise_level_bounds=(1e-10, 1e+1)),
    RationalQuadratic(length_scale=0.001) + WhiteKernel(noise_level=1.0, noise_level_bounds=(1e-10, 1e+1))
]

# %%
# Cross-validation strategy
custom_cv = KFold(n_splits=10, shuffle=True, random_state=42)

# Search grid
param_grid = {
    'kernel__k1__length_scale': np.logspace(-3, -1, 5),
    'kernel__k2__noise_level': np.logspace(-1, 2, 5)
}

# Track best model manually
best_score = -np.inf
best_model = None
best_kernel = None

# Grid search over kernels
for kernel in Base_Kernels:
    gpr = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=0, normalize_y=True)
    grid = GridSearchCV(gpr, param_grid, cv=custom_cv, scoring='neg_mean_squared_error')
    grid.fit(z_train.reshape(-1, 1), mu_train)
    
    score = grid.best_score_
    print(f"Kernel: {kernel}")
    print(f"Best score (neg MSE): {score:.4f}")
    print(f"Best params: {grid.best_params_}\n")

    if score > best_score:
        best_score = score
        best_model = grid.best_estimator_
        best_kernel = kernel

# After loop: evaluate best model on test set
y_test_pred = best_model.predict(z_test.reshape(-1, 1))
test_mse = mean_squared_error(mu_test, y_test_pred)

print(f"Best kernel: {best_model.kernel_}")
print(f"Test MSE: {test_mse:.3f}")
# Out:
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel: RBF(length_scale=0.001) + WhiteKernel(noise_level=1)
# Best score (neg MSE): -0.9613
# Best params: {'kernel__k1__length_scale': np.float64(0.1), 'kernel__k2__noise_level': np.float64(3.1622776601683795)}
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__length_scale is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel: Matern(length_scale=0.001, nu=1.5) + WhiteKernel(noise_level=1)
# Best score (neg MSE): -0.9731
# Best params: {'kernel__k1__length_scale': np.float64(0.01), 'kernel__k2__noise_level': np.float64(0.1)}
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\ricca\Documents\Unimib-Code\AstroStatistics\tf-venv\lib\site-packages\sklearn\gaussian_process\kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__alpha is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel: RationalQuadratic(alpha=1, length_scale=0.001) + WhiteKernel(noise_level=1)
# Best score (neg MSE): -0.9629
# Best params: {'kernel__k1__length_scale': np.float64(0.03162277660168379), 'kernel__k2__noise_level': np.float64(0.5623413251903491)}
#
# Best kernel: RBF(length_scale=0.459) + WhiteKernel(noise_level=0.247)
# Test MSE: 0.866

# %%
best_model.fit(z_train.reshape(-1,1), mu_train)
# Out:
# GaussianProcessRegressor(kernel=RBF(length_scale=0.1) + WhiteKernel(noise_level=3.16),
#                          normalize_y=True)

# %%
X = z_train.reshape(-1, 1)
y = mu_train.reshape(-1, 1)

gpr = best_model

# Predict over a dense grid
x_fit = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_mean, y_std = gpr.predict(x_fit, return_std=True)

# Credibility bands: ±1σ, ±2σ, ±3σ
bands = {
    '1σ': (y_mean.ravel() - 1*y_std, y_mean.ravel() + 1*y_std, 0.3),
    '2σ': (y_mean.ravel() - 2*y_std, y_mean.ravel() + 2*y_std, 0.2),
    '3σ': (y_mean.ravel() - 3*y_std, y_mean.ravel() + 3*y_std, 0.1),
}

# Plot
plt.figure(figsize=(12, 7))
plt.errorbar(z_sample, mu_sample, dmu, fmt='.k', ecolor='gray', lw=1, label='data')
plt.errorbar(z_test, mu_test, dmu_test, fmt='.r', ecolor='gray', lw=1, label='test data')
plt.errorbar(z_train, mu_train, dmu_train, fmt='.b', ecolor='gray', lw=1, label='train data')

plt.plot(x_fit, y_mean, 'k-', label='GPR mean prediction')

# Fill credibility regions
for label, (lower, upper, alpha) in bands.items():
    plt.fill_between(x_fit.ravel(), lower, upper, alpha=alpha, label=f'{label} credibility band')

plt.xlabel(r"$\mathcal{z}$")
plt.ylabel(r"$\mu$")
plt.title("Gaussian Process Regression with Credibility Bands")
plt.legend()
plt.grid(True)
plt.show()
